# %%
#import libraries
import numpy as np
import pandas as pd

# %%
#import datasets
df_1 = pd.read_csv('covid.csv')
df_2 = pd.read_csv('covid_grouped.csv')

# %%
df_1
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
df_2
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %%
#cleaning data
df_1.drop(['NewCases','NewDeaths','NewRecovered'],axis=1,inplace=True)

# %%
df_1.shape
# Out:
# (209, 14)

# %%
df_1.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  TotalDeaths  \
# 0            USA  North America  3.311981e+08     5032179     162804.0
# 1         Brazil  South America  2.127107e+08     2917562      98644.0
# 2          India           Asia  1.381345e+09     2025409      41638.0
# 3         Russia         Europe  1.459409e+08      871894      14606.0
# 4   South Africa         Africa  5.938157e+07      538184       9604.0
#
#    TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0       2576668.0    2292707.0           18296.0           15194.0
# 1       2047660.0     771258.0            8318.0           13716.0
# 2       1377384.0     606387.0            8944.0            1466.0
# 3        676357.0     180931.0            2300.0            5974.0
# 4        387316.0     141264.0             539.0            9063.0
#
#    Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region iso_alpha
# ...

# %%
df_1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop',
#        'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
df_1.head(15)[["Country/Region", "TotalCases"]]
# Out:
#    Country/Region  TotalCases
# 0             USA     5032179
# 1          Brazil     2917562
# 2           India     2025409
# 3          Russia      871894
# 4    South Africa      538184
# 5          Mexico      462690
# 6            Peru      455409
# 7           Chile      366671
# 8        Colombia      357710
# 9           Spain      354530
# 10           Iran      320117
# 11             UK      308134
# 12   Saudi Arabia      284226
# 13       Pakistan      281863
# 14     Bangladesh      249651

# %%
df_1.head(15)[["Country/Region", "TotalDeaths"]]
# Out:
#    Country/Region  TotalDeaths
# 0             USA     162804.0
# 1          Brazil      98644.0
# 2           India      41638.0
# 3          Russia      14606.0
# 4    South Africa       9604.0
# 5          Mexico      50517.0
# 6            Peru      20424.0
# 7           Chile       9889.0
# 8        Colombia      11939.0
# 9           Spain      28500.0
# 10           Iran      17976.0
# 11             UK      46413.0
# 12   Saudi Arabia       3055.0
# 13       Pakistan       6035.0
# 14     Bangladesh       3306.0

# %%
df_1.head(15)[["Country/Region", "TotalDeaths"]]
# Out:
#    Country/Region  TotalDeaths
# 0             USA     162804.0
# 1          Brazil      98644.0
# 2           India      41638.0
# 3          Russia      14606.0
# 4    South Africa       9604.0
# 5          Mexico      50517.0
# 6            Peru      20424.0
# 7           Chile       9889.0
# 8        Colombia      11939.0
# 9           Spain      28500.0
# 10           Iran      17976.0
# 11             UK      46413.0
# 12   Saudi Arabia       3055.0
# 13       Pakistan       6035.0
# 14     Bangladesh       3306.0

# %%
df_1[["Country/Region", "TotalRecovered"]]
# Out:
#             Country/Region  TotalRecovered
# 0                      USA       2576668.0
# 1                   Brazil       2047660.0
# 2                    India       1377384.0
# 3                   Russia        676357.0
# 4             South Africa        387316.0
# ..                     ...             ...
# 204             Montserrat            10.0
# 205  Caribbean Netherlands             7.0
# 206       Falkland Islands            13.0
# 207           Vatican City            12.0
# 208         Western Sahara             8.0
#
# [209 rows x 2 columns]

# %%
df_1["TotalCases"].max()
# Out:
# 5032179

# %%
df_1["TotalCases"].min()
# Out:
# 10

# %%
df_1["TotalCases"].mean()
# Out:
# 91718.4976076555

# %%
df_1.iloc[0]
# Out:
# Country/Region                USA
# Continent           North America
# Population            3.31198e+08
# TotalCases                5032179
# TotalDeaths                162804
# TotalRecovered        2.57667e+06
# ActiveCases           2.29271e+06
# Serious,Critical            18296
# Tot Cases/1M pop            15194
# Deaths/1M pop                 492
# TotalTests            6.31396e+07
# Tests/1M pop               190640
# WHO Region               Americas
# iso_alpha                     USA
# Name: 0, dtype: object

# %%
df_1.set_index("Country/Region", inplace=True)

# %%
df_1
# Out:
#                            Continent    Population  TotalCases  TotalDeaths  \
# Country/Region
# USA                    North America  3.311981e+08     5032179     162804.0
# Brazil                 South America  2.127107e+08     2917562      98644.0
# India                           Asia  1.381345e+09     2025409      41638.0
# Russia                        Europe  1.459409e+08      871894      14606.0
# South Africa                  Africa  5.938157e+07      538184       9604.0
# ...                              ...           ...         ...          ...
# Montserrat             North America  4.992000e+03          13          1.0
# Caribbean Netherlands  North America  2.624700e+04          13          NaN
# Falkland Islands       South America  3.489000e+03          13          NaN
# Vatican City                  Europe  8.010000e+02          12          NaN
# Western Sahara                Africa  5.986820e+05          10          1.0
#
# ...

# %%
df_1.loc["Egypt"]
# Out:
# Continent                         Africa
# Population                   1.02517e+08
# TotalCases                         95006
# TotalDeaths                         4951
# TotalRecovered                     48898
# ActiveCases                        41157
# Serious,Critical                      41
# Tot Cases/1M pop                     927
# Deaths/1M pop                         48
# TotalTests                        135000
# Tests/1M pop                        1317
# WHO Region          EasternMediterranean
# iso_alpha                            EGY
# Name: Egypt, dtype: object

# %%
#working with missed Data
df_1.fillna(0)
# Out:
#                            Continent    Population  TotalCases  TotalDeaths  \
# Country/Region
# USA                    North America  3.311981e+08     5032179     162804.0
# Brazil                 South America  2.127107e+08     2917562      98644.0
# India                           Asia  1.381345e+09     2025409      41638.0
# Russia                        Europe  1.459409e+08      871894      14606.0
# South Africa                  Africa  5.938157e+07      538184       9604.0
# ...                              ...           ...         ...          ...
# Montserrat             North America  4.992000e+03          13          1.0
# Caribbean Netherlands  North America  2.624700e+04          13          0.0
# Falkland Islands       South America  3.489000e+03          13          0.0
# Vatican City                  Europe  8.010000e+02          12          0.0
# Western Sahara                Africa  5.986820e+05          10          1.0
#
# ...
